# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Covid Data.csv")

# %%
# df.dtypes
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1048575, step=1)

# %%
df.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
df.rename(columns={"CLASIFFICATION_FINAL":"CLASSIFICATION_FINAL"}, inplace=True)

# %%
df.replace([97,98,99],np.nan,inplace=True)

# %%
df["SEX"].replace({1:"female", 2:"male"},inplace=True)
df["PREGNANT"].replace({1:"yes", 2:"no"},inplace=True)
df["DIABETES"].replace({1:"yes", 2:"no"},inplace=True)
df["COPD"].replace({1:"yes", 2:"no"},inplace=True)
df["ASTHMA"].replace({1:"yes", 2:"no"},inplace=True)
df["INMSUPR"].replace({1:"yes", 2:"no"},inplace=True)
df["HIPERTENSION"].replace({1:"yes", 2:"no"},inplace=True)
df["CARDIOVASCULAR"].replace({1:"yes", 2:"no"},inplace=True)
df["RENAL_CHRONIC"].replace({1:"yes", 2:"no"},inplace=True)
df["OTHER_DISEASE"].replace({1:"yes", 2:"no"},inplace=True)
df["OBESITY"].replace({1:"yes", 2:"no"},inplace=True)
df["PATIENT_TYPE"].replace({1:"Return Home", 2:"Hospitalized"},inplace=True)
df["TOBACCO"].replace({1:"yes", 2:"no"},inplace=True)
df["ICU"].replace({1:"Yes", 2:"no"},inplace=True)
# Out:
# C:\Users\My\AppData\Local\Temp\ipykernel_11144\1894502043.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["SEX"].replace({1:"female", 2:"male"},inplace=True)
# C:\Users\My\AppData\Local\Temp\ipykernel_11144\1894502043.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT     SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1  female   Return Home  03/05/2020      NaN        1.0
# 1      2             1    male   Return Home  03/06/2020      NaN        1.0
# 2      2             1    male  Hospitalized  09/06/2020      1.0        2.0
# 3      2             1  female   Return Home  12/06/2020      NaN        2.0
# 4      2             1    male   Return Home  21/06/2020      NaN        2.0
#
#     AGE PREGNANT DIABETES  ... ASTHMA INMSUPR HIPERTENSION OTHER_DISEASE  \
# 0  65.0       no       no  ...     no      no          yes            no
# 1  72.0      NaN       no  ...     no      no          yes            no
# 2  55.0      NaN      yes  ...     no      no           no            no
# 3  53.0       no       no  ...     no      no           no            no
# 4  68.0      NaN      yes  ...     no      no          yes            no
#
# ...

# %%
df.dropna()
# Out:
#          USMER  MEDICAL_UNIT     SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 5            2             1  female  Hospitalized  9999-99-99      2.0
# 8            2             1  female  Hospitalized  9999-99-99      2.0
# 9            2             1  female  Hospitalized  9999-99-99      2.0
# 16           2             1  female  Hospitalized  9999-99-99      2.0
# 56           2             1  female  Hospitalized  9999-99-99      1.0
# ...        ...           ...     ...           ...         ...      ...
# 1048535      1            13  female  Hospitalized  9999-99-99      2.0
# 1048553      2            13  female  Hospitalized  9999-99-99      2.0
# 1048554      2            13  female  Hospitalized  9999-99-99      2.0
# 1048567      1            13  female  Hospitalized  9999-99-99      2.0
# 1048569      1            13  female  Hospitalized  9999-99-99      2.0
#
#          PNEUMONIA   AGE PREGNANT DIABETES  ... ASTHMA INMSUPR HIPERTENSION  \
# ...

# %%
df["SEX"].value_counts()
# Out:
# SEX
# female    525064
# male      523511
# Name: count, dtype: int64

# %%
df["PATIENT_TYPE"].value_counts()
# Out:
# PATIENT_TYPE
# Return Home     848544
# Hospitalized    200031
# Name: count, dtype: int64

# %%
df["PREGNANT"].value_counts()
# Out:
# PREGNANT
# no     513179
# yes      8131
# Name: count, dtype: int64

# %%
df["high_risk"] = np.where(
    (df["AGE"] >= 65) |  
    (df["PREGNANT"] == "yes") |  
    (df["DIABETES"] == "yes") | 
    (df["COPD"] == "yes") |
    (df["ASTHMA"] =="yes") |
    (df["INMSUPR"] == "yes") |  
    (df["HIPERTENSION"] == "yes") | 
    (df["CARDIOVASCULAR"] == "yes") |
    (df["RENAL_CHRONIC"] =="yes") |
    (df["OTHER_DISEASE"] == "yes") |  
    (df["OBESITY"] == "yes") | 
    (df["TOBACCO"] == "yes") |
    (df["ICU"] =="yes") , 
    "yes", "no")

# %%
df["high_risk"].value_counts()
# Out:
# high_risk
# no     591818
# yes    456757
# Name: count, dtype: int64

# %%
df["high_risk_not_pregnant"] = np.where(
    (df["AGE"] >= 65) |  
    # (df["PREGNANT"] == "yes") |  
    (df["DIABETES"] == "yes") | 
    (df["COPD"] == "yes") |
    (df["ASTHMA"] =="yes") |
    (df["INMSUPR"] == "yes") |  
    (df["HIPERTENSION"] == "yes") | 
    (df["CARDIOVASCULAR"] == "yes") |
    (df["RENAL_CHRONIC"] =="yes") |
    (df["OTHER_DISEASE"] == "yes") |  
    (df["OBESITY"] == "yes") | 
    (df["TOBACCO"] == "yes") |
    (df["ICU"] =="yes") , 
    "yes", "no")

# %%
df["high_risk_not_pregnant"].value_counts()
# Out:
# high_risk_not_pregnant
# no     598230
# yes    450345
# Name: count, dtype: int64

# %%
df["Low_risk"] = np.where(
    (df["AGE"] <= 65) |  
    (df["PREGNANT"] == "yes") |  
    (df["DIABETES"] == "yes") | 
    (df["COPD"] == "yes") |
    (df["ASTHMA"] =="yes") |
    (df["INMSUPR"] == "yes") |  
    (df["HIPERTENSION"] == "yes") | 
    (df["CARDIOVASCULAR"] == "yes") |
    (df["RENAL_CHRONIC"] =="yes") |
    (df["OTHER_DISEASE"] == "yes") |  
    (df["OBESITY"] == "yes") | 
    (df["TOBACCO"] == "yes") |
    (df["ICU"] =="yes") , 
    "yes", "no")

# %%
df["Low_risk"].value_counts()
# Out:
# Low_risk
# yes    1020487
# no       28088
# Name: count, dtype: int64

# %%
df["Low_risk_not_pregnant"] = np.where(
    (df["AGE"] <= 65) |  
    # (df["PREGNANT"] == "yes") |  
    (df["DIABETES"] == "yes") | 
    (df["COPD"] == "yes") |
    (df["ASTHMA"] =="yes") |
    (df["INMSUPR"] == "yes") |  
    (df["HIPERTENSION"] == "yes") | 
    (df["CARDIOVASCULAR"] == "yes") |
    (df["RENAL_CHRONIC"] =="yes") |
    (df["OTHER_DISEASE"] == "yes") |  
    (df["OBESITY"] == "yes") | 
    (df["TOBACCO"] == "yes") |
    (df["ICU"] =="yes") , 
    "yes", "no")

# %%
df["Low_risk_not_pregnant"].value_counts()
# Out:
# Low_risk_not_pregnant
# yes    1020479
# no       28096
# Name: count, dtype: int64

# %%
df["mid_risk"] = np.where(
    (df["AGE"] >= 30) |  
    (df["PREGNANT"] == "yes") |  
    (df["DIABETES"] == "yes") | 
    (df["COPD"] == "yes") |
    (df["ASTHMA"] =="yes") |
    (df["INMSUPR"] == "yes") |  
    (df["HIPERTENSION"] == "yes") | 
    (df["CARDIOVASCULAR"] == "yes") |
    (df["RENAL_CHRONIC"] =="yes") |
    (df["OTHER_DISEASE"] == "yes") |  
    (df["OBESITY"] == "yes") | 
    (df["TOBACCO"] == "yes") |
    (df["ICU"] =="yes") , 
    "yes", "no")

# %%
df["mid_risk"].value_counts()
# Out:
# mid_risk
# yes    854556
# no     194019
# Name: count, dtype: int64

# %%
df["mid_risk_not_pregnant"] = np.where(
    (df["AGE"] >= 30) |  
    # (df["PREGNANT"] == "yes") |  
    (df["DIABETES"] == "yes") | 
    (df["COPD"] == "yes") |
    (df["ASTHMA"] =="yes") |
    (df["INMSUPR"] == "yes") |  
    (df["HIPERTENSION"] == "yes") | 
    (df["CARDIOVASCULAR"] == "yes") |
    (df["RENAL_CHRONIC"] =="yes") |
    (df["OTHER_DISEASE"] == "yes") |  
    (df["OBESITY"] == "yes") | 
    (df["TOBACCO"] == "yes") |
    (df["ICU"] =="yes") , 
    "yes", "no")

# %%
df["mid_risk_not_pregnant"].value_counts()
# Out:
# mid_risk_not_pregnant
# yes    850624
# no     197951
# Name: count, dtype: int64

# %%
# df.head(50)
df["high_risk"].value_counts()
# Out:
# high_risk
# no     591818
# yes    456757
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#    USMER  MEDICAL_UNIT     SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1  female   Return Home  03/05/2020      NaN        1.0
# 1      2             1    male   Return Home  03/06/2020      NaN        1.0
# 2      2             1    male  Hospitalized  09/06/2020      1.0        2.0
# 3      2             1  female   Return Home  12/06/2020      NaN        2.0
# 4      2             1    male   Return Home  21/06/2020      NaN        2.0
# 5      2             1  female  Hospitalized  9999-99-99      2.0        1.0
# 6      2             1  female   Return Home  9999-99-99      NaN        2.0
# 7      2             1  female   Return Home  9999-99-99      NaN        1.0
# 8      2             1  female  Hospitalized  9999-99-99      2.0        2.0
# 9      2             1  female  Hospitalized  9999-99-99      2.0        2.0
#
#     AGE PREGNANT DIABETES  ... RENAL_CHRONIC TOBACCO CLASSIFICATION_FINAL  \
# ...

# %%
df["survived"] = np.where(
    (df["AGE"] >= 65) |  
    (df["PREGNANT"] == "yes") |  
    (df["DIABETES"] == "yes") | 
    (df["COPD"] == "yes") |
    (df["ASTHMA"] =="yes") |
    (df["INMSUPR"] == "yes") |  
    (df["HIPERTENSION"] == "yes") | 
    (df["CARDIOVASCULAR"] == "yes") |
    (df["RENAL_CHRONIC"] =="yes") |
    (df["OTHER_DISEASE"] == "yes") |  
    (df["OBESITY"] == "yes") | 
    (df["TOBACCO"] == "yes") |
    (df["ICU"] =="yes") , 
    "yes", "no")

# %%
df["SEX"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='SEX'>

# %%
df_groupby = df.groupby(["SEX","PATIENT_TYPE"])
df_groupby.size().plot(kind="bar")
# Out:
# <Axes: xlabel='SEX,PATIENT_TYPE'>

# %%
df_groupby = df.groupby(["SEX","high_risk"])
df_groupby.size().plot(kind="pie")
# Out:
# <Axes: >

# %%
df_groupby=df.groupby("SEX")["high_risk"].value_counts().plot(kind="bar")

# %%
# df_groupby = df.groupby(["SEX","high_risk","Low_risk"],as_index=False[""])
